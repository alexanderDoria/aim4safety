# %% [markdown]
# # Prominent Data Sources

# %%
import pandas as pd

# %% [markdown]
# ## Gun Violence Archive (GVA)
# The Gun Violence Archive is a widely recognized and frequently referenced source for information on gun violence incidents, including mass shootings, in the United States. They collect and analyze data from various sources, including law enforcement, media reports, and public sources. Their website provides access to a comprehensive database of mass shootings and other gun violence incidents https://www.gunviolencearchive.org/mass-shooting

# %%
df_gva = pd.read_csv('../data/gunviolencearchive.csv')

# %%
df_gva
# Out:
#       Incident ID  Incident Date           State City Or County  \
# 0         2614735   June 2, 2023           Texas    San Antonio
# 1         2614353   May 31, 2023            Ohio      Cleveland
# 2         2613375   May 31, 2023            Ohio     Cincinnati
# 3         2613087   May 31, 2023  North Carolina   Fayetteville
# 4         2612967   May 30, 2023    Pennsylvania        Lebanon
# ...           ...            ...             ...            ...
# 1995      1712386  June 22, 2020        Illinois        Chicago
# 1996      1713668  June 22, 2020            Ohio       Columbus
# 1997      1711747  June 21, 2020        New York        Buffalo
# 1998      1711626  June 21, 2020           Texas         Austin
# 1999      1711410  June 21, 2020       Minnesota    Minneapolis
#
#                           Address  # Victims Injured  # Victims Killed  \
# 0     5100 block of Eisenhauer Rd                  3                 1
# ...

# %% [markdown]
# ## Mother Jones Mass Shootings Database
# Mother Jones, a nonprofit news organization, maintains a database that focuses on mass shootings in public places in the United States. They provide in-depth details about each incident, including the location, date, number of victims, and other relevant information. Their database is regularly updated and widely referenced.
# https://docs.google.com/spreadsheets/d/1b9o6uDO18sLxBqPwl_Gh9bnhW-ev_dABH83M5Vb5L8o/edit#gid=0

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/1b9o6uDO18sLxBqPwl_Gh9bnhW-ev_dABH83M5Vb5L8o/edit#gid=0"
url_1 = sheet_url.replace("/edit#gid=", "/export?format=csv&gid=")

# %%
df_mj = pd.read_csv(url_1)

# %%
df_mj
# Out:
#                                       case                location       date  \
# 0         New Mexico neighborhood shooting  Farmington, New Mexico    5/15/23
# 1               Texas outlet mall shooting            Allen, Texas     5/6/23
# 2                 Louisville bank shooting    Louisville, Kentucky    4/10/23
# 3      Nashville Christian school shooting    Nashville, Tennessee    3/27/23
# 4       Michigan State University shooting  East Lansing, Michigan    2/13/23
# ..                                     ...                     ...        ...
# 139        Shopping centers spree killings       Palm Bay, Florida  4/23/1987
# 140  United States Postal Service shooting        Edmond, Oklahoma  8/20/1986
# 141         San Ysidro McDonald's massacre  San Ysidro, California  7/18/1984
# 142              Dallas nightclub shooting           Dallas, Texas  6/29/1984
# 143                  Welding shop shooting          Miami, Florida  8/20/1982
#
# ...

# %%
df_mj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case                              144 non-null    object
#  1   location                          144 non-null    object
#  2   date                              144 non-null    object
#  3   summary                           144 non-null    object
#  4   fatalities                        144 non-null    int64
#  5   injured                           144 non-null    int64
#  6   total_victims                     144 non-null    int64
#  7   location.1                        144 non-null    object
#  8   age_of_shooter                    144 non-null    object
#  9   prior_signs_mental_health_issues  144 non-null    object
#  10  mental_health_details             144 non-null    object
# ...

# %% [markdown]
# ## Violence Project's Mass Shooter Database
# The Violence Project’s Mass Shooter Database contains extensive details about public mass shootings in the US and their perpetrators, weapons, and victims, with a goal of “finding pathways to prevention.” The database, funded by a National Institute of Justice grant, covers 170+ shootings between 1966 and early 2020. Examples of the variables include: the perpetrator’s employment status, known prejudices, and experience with mental illness; the victims’ relationship to the perpetrator and estimated years of life they lost; and the firearms’ make, model, and method of acquisition.
# https://www.theviolenceproject.org/key-findings/

# %%
filepath = '../data/violence_project.xlsx'
sheets = pd.ExcelFile(filepath)

# %%
sheets.sheet_names
# Out:
# ['Table of Contents',
#  'FAQs',
#  'New in Each Version',
#  'Codebook',
#  'Full Database',
#  'Firearms Data',
#  'Victims Data',
#  'Community Data',
#  'Trend Data']

# %%
df_data = pd.read_excel(filepath, sheet_name='Full Database')

# %%
df_data.sample()
# Out:
#     Case # Shooter Last Name Shooter First Name  Full Date Day of Week   Day  \
# 157  158.0              Cruz            Nikolas  2/14/2018   Wednesday  14.0
#
#      Month    Year Street Number     Street Name  ... Interest in Firearms  \
# 157    2.0  2018.0        5901.0  Pine Island Rd  ...                  1.0
#
#     Firearm Proficiency Total Firearms Brought to the Scene  \
# 157                 2.0                                 1.0
#
#      Other Weapons or Gear  Specify Other Weapons or Gear  On-Scene Outcome  \
# 157                    1.0       smoke grenades, gas mask               2.0
#
#      Who Killed Shooter On Scene  Attempt to Flee  Insanity Defense  \
# 157                          0.0              1.0               3.0
#
#     Criminal Sentence
# 157               2.0
#
# [1 rows x 153 columns]

# %%
df_victims = pd.read_excel(filepath, sheet_name='Victims Data')

# %%
df_victims.sample(5)
# Out:
#     Case # Shooter Last Name Shooter First Name   Full Date  \
# 796  129.0             Lanza               Adam  12/14/2012
# 173   29.0           Huberty              James   7/18/1984
# 255   40.0            Harris             Joseph  10/10/1991
# 282   42.0                Lu               Gang   11/1/1991
# 754  126.0            Holmes              James   7/20/2012
#
#                         Victim Name   Age  Gender  Race  Knew Shooter  \
# 796                   Emilie Parker   6.0     1.0   0.0           0.0
# 173               Margarita Padilla  18.0     1.0   2.0           0.0
# 255           Joseph M. VanderPaauw  59.0     0.0   NaN           2.0
# 282                 Robert A. Smith  45.0     0.0   0.0           1.0
# 754  Alexander Jonathan "A.J." Boik  18.0     0.0   0.0           0.0
#
#     If Known, Relationship to Shooter  Relationship to Shooter  \
# 796                               NaN                      0.0
# ...

# %%
df_firearms = pd.read_excel(filepath, sheet_name='Firearms Data')

# %%
df_firearms.sample(5)
# Out:
#     Case # Shooter Last Name Shooter First Name            Full Date  \
# 207  100.0           Roberts            Charles  2006-10-02 00:00:00
# 396  186.0             Louis            Michael  2022-06-01 00:00:00
# 310  150.0          Santiago            Esteban  2017-01-06 00:00:00
# 319  154.0           Paddock            Stephen  2017-10-01 00:00:00
# 203   98.0              Huff               Kyle  2006-03-25 00:00:00
#
#                                         Make and Model  Classification  \
# 207                     .30-06 Ruger bolt-action rifle             2.0
# 396                                  AR-15-style rifle             3.0
# 310                  9mm Walther semi-automatic pistol             0.0
# 319  .223-caliber Daniel Defense DDM4V11 AR-15 with...             3.0
# 203  12-gauge Winchester Defender 1300 pump-action ...             1.0
#
#      Caliber  Used in Shooting?  Modified  Large Capacity Magazine  \
# ...
